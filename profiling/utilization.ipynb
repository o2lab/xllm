# %%
import os
import numpy as np
import pandas as pd

# %%
q4_data_file = "ncu_report_full_q4_2layers_utilization.csv"
q8_data_file = "ncu_report_full_q8_2layers_utilization.csv"

interested_metrics = [
    "sm__pipe_tensor_cycles_active.avg.pct_of_peak_sustained_active", # tensor_precision_fu_utilization
    "smsp__sass_thread_inst_executed_op_fp16_pred_on.sum",  # inst_fp_16
    "smsp__sass_thread_inst_executed_op_fp32_pred_on.sum",
    "smsp__sass_thread_inst_executed_op_fp64_pred_on.sum",
    "smsp__sass_thread_inst_executed_op_integer_pred_on.sum",

]

# %%
def is_interested(col_name):
    for m in interested_metrics:
        if m + " " in col_name:
            return True
    return False

# %%
q4_data = pd.read_csv(q4_data_file, thousands=',')
cols = q4_data.columns

# %%
selected_cols = cols[[0,3,4,6,8]]

# %%
list(selected_cols)
# Out:
# ['ID',
#  'Estimated Speedup',
#  'Runtime Improvement""(0)',
#  'Function Name',
#  'Demangled Name']

# %%
appending_cols = [col for col in cols if is_interested(col)]
len(appending_cols)
# Out:
# 5

# %%
appending_cols
# Out:
# ['sm__pipe_tensor_cycles_active.avg.pct_of_peak_sustained_active [%]',
#  'smsp__sass_thread_inst_executed_op_fp16_pred_on.sum [inst]',
#  'smsp__sass_thread_inst_executed_op_fp32_pred_on.sum [inst]',
#  'smsp__sass_thread_inst_executed_op_fp64_pred_on.sum [inst]',
#  'smsp__sass_thread_inst_executed_op_integer_pred_on.sum [inst]']

# %%
q4_stat = q4_data.loc[:,list(selected_cols)+list(appending_cols)]
q4_stat
# Out:
#       ID  Estimated Speedup  Runtime Improvement""(0)           Function Name  \
# 0      0                  0                         0            rms_norm_f32
# 1      1                  0                         0             k_bin_bcast
# 2      2                  0                         0  dequantize_mul_mat_vec
# 3      3                  0                         0            soft_max_f32
# 4      4                  0                         0       k_argsort_f32_i32
# ..   ...                ...                       ...                     ...
# 295  295                  0                         0             k_bin_bcast
# 296  296                  0                         0           quantize_q8_1
# 297  297                  0                         0           mul_mat_vec_q
# 298  298                  0                         0             k_bin_bcast
# 299  299                  0                         0             k_bin_bcast
#
#                                         Demangled Name  \
# 0    void rms_norm_f32<(int)1024>(const float *, fl...
# 1    void k_bin_bcast<&op_mul, float, float, float>...
# 2    void dequantize_mul_mat_vec<(int)1, (int)1, &c...
# 3    void soft_max_f32<(bool)1, (int)0, (int)0>(con...
# 4    void k_argsort_f32_i32<(ggml_sort_order)1>(con...
# ..                                                 ...
# 295  void k_bin_bcast<&op_mul, float, float, float>...
# 296     quantize_q8_1(const float *, void *, int, int)
# 297  void mul_mat_vec_q<(int)32, (int)8, block_q8_0...
# 298  void k_bin_bcast<&op_mul, float, float, float>...
# 299  void k_bin_bcast<&op_add, float, float, float>...
#
#      sm__pipe_tensor_cycles_active.avg.pct_of_peak_sustained_active [%]  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 295                                                  0
# 296                                                  0
# 297                                                  0
# 298                                                  0
# 299                                                  0
#
#      smsp__sass_thread_inst_executed_op_fp16_pred_on.sum [inst]  \
# 0                                                    0
# 1                                                    0
# 2                                                32768
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 295                                                  0
# 296                                                  0
# 297                                           14680064
# 298                                                  0
# 299                                                  0
#
#      smsp__sass_thread_inst_executed_op_fp32_pred_on.sum [inst]  \
# 0                                                21504
# 1                                                14336
# 2                                                33800
# 3                                                  408
# 4                                                   24
# ..                                                 ...
# 295                                              50176
# 296                                             215488
# 297                                           15208448
# 298                                              14336
# 299                                              14336
#
#      smsp__sass_thread_inst_executed_op_fp64_pred_on.sum [inst]  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 295                                                  0
# 296                                                  0
# 297                                                  0
# 298                                                  0
# 299                                                  0
#
#      smsp__sass_thread_inst_executed_op_integer_pred_on.sum [inst]
# 0                                                34880
# 1                                               245760
# 2                                                37896
# 3                                                  824
# 4                                                  672
# ..                                                 ...
# 295                                             860160
# 296                                             302848
# 297                                           37883904
# 298                                             249855
# 299                                             245760
#
# [300 rows x 10 columns]

# %%
q4_stat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 10 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   ID                                                                  300 non-null    int64
#  1   Estimated Speedup                                                   300 non-null    float64
#  2   Runtime Improvement""(0)                                            300 non-null    float64
#  3   Function Name                                                       300 non-null    object
#  4   Demangled Name                                                      300 non-null    object
#  5   sm__pipe_tensor_cycles_active.avg.pct_of_peak_sustained_active [%]  300 non-null    float64
#  6   smsp__sass_thread_inst_executed_op_fp16_pred_on.sum [inst]          300 non-null    int64
#  7   smsp__sass_thread_inst_executed_op_fp32_pred_on.sum [inst]          300 non-null    int64
#  8   smsp__sass_thread_inst_executed_op_fp64_pred_on.sum [inst]          300 non-null    int64
#  9   smsp__sass_thread_inst_executed_op_integer_pred_on.sum [inst]       300 non-null    int64
# dtypes: float64(3), int64(5), object(2)
# memory usage: 23.6+ KB

# %%
# for col in q4_stat.columns[5:]:
#     q4_stat[col] = pd.to_numeric(q4_stat[col])

# %%
q4_stat.iloc[:,4:].dtypes
# Out:
# Demangled Name                                                         object
# sm__pipe_tensor_cycles_active.avg.pct_of_peak_sustained_active [%]    float64
# smsp__sass_thread_inst_executed_op_fp16_pred_on.sum [inst]              int64
# smsp__sass_thread_inst_executed_op_fp32_pred_on.sum [inst]              int64
# smsp__sass_thread_inst_executed_op_fp64_pred_on.sum [inst]              int64
# smsp__sass_thread_inst_executed_op_integer_pred_on.sum [inst]           int64
# dtype: object

# %%
q4_stat.iloc[:,4:]["smsp__sass_thread_inst_executed_op_fp16_pred_on.sum [inst]"]
# Out:
# 0             0
# 1             0
# 2         32768
# 3             0
# 4             0
#          ...
# 295           0
# 296           0
# 297    14680064
# 298           0
# 299           0
# Name: smsp__sass_thread_inst_executed_op_fp16_pred_on.sum [inst], Length: 300, dtype: int64

# %%
pd.options.display.float_format = '{:.0f}'.format

# %%
res = q4_stat.iloc[:,4:].groupby(['Demangled Name'], sort=True).mean()
res
# Out:
#                                                     sm__pipe_tensor_cycles_active.avg.pct_of_peak_sustained_active [%]  \
# Demangled Name
# k_compute_batched_ptrs(const __half *, const __...                                                  0
# k_sum_rows_f32(const float *, float *, int)                                                         0
# quantize_q8_1(const float *, void *, int, int)                                                      0
# silu_f32(const float *, float *, int)                                                               0
# turing_h1688gemm_256x64_ldg8_stages_32x1_tn                                                        29
# void convert_unary<__half, float>(const void *,...                                                  0
# void convert_unary<float, __half>(const void *,...                                                  0
# void cpy_f32_f16<&cpy_1_f32_f16>(const char *, ...                                                  0
# void cpy_f32_f16<&cpy_1_f32_f32>(const char *, ...                                                  0
# void dequantize_mul_mat_vec<(int)1, (int)1, &co...                                                  0
# void k_argsort_f32_i32<(ggml_sort_order)1>(cons...                                                  0
# void k_bin_bcast<&op_add, float, float, float>(...                                                  0
# void k_bin_bcast<&op_div, float, float, float>(...                                                  0
# void k_bin_bcast<&op_mul, float, float, float>(...                                                  0
# void k_get_rows_float<float, float>(const T1 *,...                                                  0
# void mul_mat_vec_q<(int)32, (int)8, block_q8_0,...                                                  0
# void rms_norm_f32<(int)1024>(const float *, flo...                                                  0
# void rope<float, (bool)1>(const T1 *, T1 *, int...                                                  0
# void soft_max_f32<(bool)1, (int)0, (int)0>(cons...                                                  0
# void soft_max_f32<(bool)1, (int)64, (int)64>(co...                                                  0
#
#                                                     smsp__sass_thread_inst_executed_op_fp16_pred_on.sum [inst]  \
# Demangled Name
# k_compute_batched_ptrs(const __half *, const __...                                                  0
# k_sum_rows_f32(const float *, float *, int)                                                         0
# quantize_q8_1(const float *, void *, int, int)                                                      0
# silu_f32(const float *, float *, int)                                                               0
# turing_h1688gemm_256x64_ldg8_stages_32x1_tn                                                   1839104
# void convert_unary<__half, float>(const void *,...                                               3072
# void convert_unary<float, __half>(const void *,...                                                  0
# void cpy_f32_f16<&cpy_1_f32_f16>(const char *, ...                                                  0
# void cpy_f32_f16<&cpy_1_f32_f32>(const char *, ...                                                  0
# void dequantize_mul_mat_vec<(int)1, (int)1, &co...                                              32768
# void k_argsort_f32_i32<(ggml_sort_order)1>(cons...                                                  0
# void k_bin_bcast<&op_add, float, float, float>(...                                                  0
# void k_bin_bcast<&op_div, float, float, float>(...                                                  0
# void k_bin_bcast<&op_mul, float, float, float>(...                                                  0
# void k_get_rows_float<float, float>(const T1 *,...                                                  0
# void mul_mat_vec_q<(int)32, (int)8, block_q8_0,...                                           10373413
# void rms_norm_f32<(int)1024>(const float *, flo...                                                  0
# void rope<float, (bool)1>(const T1 *, T1 *, int...                                                  0
# void soft_max_f32<(bool)1, (int)0, (int)0>(cons...                                                  0
# void soft_max_f32<(bool)1, (int)64, (int)64>(co...                                                  0
#
#                                                     smsp__sass_thread_inst_executed_op_fp32_pred_on.sum [inst]  \
# Demangled Name
# k_compute_batched_ptrs(const __half *, const __...                                                 64
# k_sum_rows_f32(const float *, float *, int)                                                       131
# quantize_q8_1(const float *, void *, int, int)                                                  94551
# silu_f32(const float *, float *, int)                                                           71680
# turing_h1688gemm_256x64_ldg8_stages_32x1_tn                                                         0
# void convert_unary<__half, float>(const void *,...                                                  0
# void convert_unary<float, __half>(const void *,...                                                  0
# void cpy_f32_f16<&cpy_1_f32_f16>(const char *, ...                                               4096
# void cpy_f32_f16<&cpy_1_f32_f32>(const char *, ...                                              16384
# void dequantize_mul_mat_vec<(int)1, (int)1, &co...                                              33800
# void k_argsort_f32_i32<(ggml_sort_order)1>(cons...                                                 24
# void k_bin_bcast<&op_add, float, float, float>(...                                              14336
# void k_bin_bcast<&op_div, float, float, float>(...                                                  9
# void k_bin_bcast<&op_mul, float, float, float>(...                                              25960
# void k_get_rows_float<float, float>(const T1 *,...                                                512
# void mul_mat_vec_q<(int)32, (int)8, block_q8_0,...                                           11397157
# void rms_norm_f32<(int)1024>(const float *, flo...                                              21504
# void rope<float, (bool)1>(const T1 *, T1 *, int...                                              23040
# void soft_max_f32<(bool)1, (int)0, (int)0>(cons...                                                408
# void soft_max_f32<(bool)1, (int)64, (int)64>(co...                                              59392
#
#                                                     smsp__sass_thread_inst_executed_op_fp64_pred_on.sum [inst]  \
# Demangled Name
# k_compute_batched_ptrs(const __half *, const __...                                                  0
# k_sum_rows_f32(const float *, float *, int)                                                         0
# quantize_q8_1(const float *, void *, int, int)                                                      0
# silu_f32(const float *, float *, int)                                                               0
# turing_h1688gemm_256x64_ldg8_stages_32x1_tn                                                         0
# void convert_unary<__half, float>(const void *,...                                                  0
# void convert_unary<float, __half>(const void *,...                                                  0
# void cpy_f32_f16<&cpy_1_f32_f16>(const char *, ...                                                  0
# void cpy_f32_f16<&cpy_1_f32_f32>(const char *, ...                                                  0
# void dequantize_mul_mat_vec<(int)1, (int)1, &co...                                                  0
# void k_argsort_f32_i32<(ggml_sort_order)1>(cons...                                                  0
# void k_bin_bcast<&op_add, float, float, float>(...                                                  0
# void k_bin_bcast<&op_div, float, float, float>(...                                                  0
# void k_bin_bcast<&op_mul, float, float, float>(...                                                  0
# void k_get_rows_float<float, float>(const T1 *,...                                                  0
# void mul_mat_vec_q<(int)32, (int)8, block_q8_0,...                                                  0
# void rms_norm_f32<(int)1024>(const float *, flo...                                                  0
# void rope<float, (bool)1>(const T1 *, T1 *, int...                                                  0
# void soft_max_f32<(bool)1, (int)0, (int)0>(cons...                                                  0
# void soft_max_f32<(bool)1, (int)64, (int)64>(co...                                                  0
#
#                                                     smsp__sass_thread_inst_executed_op_integer_pred_on.sum [inst]
# Demangled Name
# k_compute_batched_ptrs(const __half *, const __...                                               2062
# k_sum_rows_f32(const float *, float *, int)                                                        73
# quantize_q8_1(const float *, void *, int, int)                                                 132882
# silu_f32(const float *, float *, int)                                                           57344
# turing_h1688gemm_256x64_ldg8_stages_32x1_tn                                                   1775616
# void convert_unary<__half, float>(const void *,...                                              12288
# void convert_unary<float, __half>(const void *,...                                              12288
# void cpy_f32_f16<&cpy_1_f32_f16>(const char *, ...                                              91141
# void cpy_f32_f16<&cpy_1_f32_f32>(const char *, ...                                             356414
# void dequantize_mul_mat_vec<(int)1, (int)1, &co...                                              37896
# void k_argsort_f32_i32<(ggml_sort_order)1>(cons...                                                672
# void k_bin_bcast<&op_add, float, float, float>(...                                             245760
# void k_bin_bcast<&op_div, float, float, float>(...                                                121
# void k_bin_bcast<&op_mul, float, float, float>(...                                             446574
# void k_get_rows_float<float, float>(const T1 *,...                                               9824
# void mul_mat_vec_q<(int)32, (int)8, block_q8_0,...                                           30485687
# void rms_norm_f32<(int)1024>(const float *, flo...                                              34880
# void rope<float, (bool)1>(const T1 *, T1 *, int...                                              39680
# void soft_max_f32<(bool)1, (int)0, (int)0>(cons...                                                824
# void soft_max_f32<(bool)1, (int)64, (int)64>(co...                                              61376

# %%
res.to_csv("./q4_utilization.csv")
