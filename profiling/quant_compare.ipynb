# %%
import os
import numpy as np
import pandas as pd
# Out:
# /tmp/ipykernel_914/2916776140.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
q4_data_file = "ncu_report_full_q4_2layers_utilization.csv"
q8_data_file = "ncu_report_full_q8_2layers_utilization.csv"

interested_metrics = [
    "sm__pipe_tensor_cycles_active.avg.pct_of_peak_sustained_active", # tensor_precision_fu_utilization
    "smsp__sass_thread_inst_executed_op_fp16_pred_on.sum",  # inst_fp_16
    "smsp__sass_thread_inst_executed_op_fp32_pred_on.sum",
    "smsp__sass_thread_inst_executed_op_fp64_pred_on.sum",
    "smsp__sass_thread_inst_executed_op_integer_pred_on.sum",

]

# %%
def is_interested(col_name):
    for m in interested_metrics:
        if m + " " in col_name:
            return True
    return False

# %%
def get_aggregated_stat(source_data_path):
    print("=== Reading data:", source_data_path)
    source_data = pd.read_csv(source_data_path, thousands=',')
    cols = source_data.columns
    selected_cols = cols[[0,3,4,6,8]]
    appending_cols = [col for col in cols if is_interested(col)]
    print("Interested metrics in data file:",len(appending_cols))
    source_stat = source_data.loc[:,list(selected_cols)+list(appending_cols)]
    print(source_stat.info())
    print("Data types:", source_stat.iloc[:,4:].dtypes)
    res = source_stat.iloc[:,4:].groupby(['Demangled Name'], sort=True).mean()
    print("=== End of Processing:", source_data_path)
    return res

# %%
q4_agg = get_aggregated_stat(q4_data_file)
# Out:
# === Reading data: ncu_report_full_q4_2layers_utilization.csv
# Interested metrics in data file: 5
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 10 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   ID                                                                  300 non-null    int64
#  1   Estimated Speedup                                                   300 non-null    float64
#  2   Runtime Improvement""(0)                                            300 non-null    float64
#  3   Function Name                                                       300 non-null    object
#  4   Demangled Name                                                      300 non-null    object
#  5   sm__pipe_tensor_cycles_active.avg.pct_of_peak_sustained_active [%]  300 non-null    float64
#  6   smsp__sass_thread_inst_executed_op_fp16_pred_on.sum [inst]          300 non-null    int64
#  7   smsp__sass_thread_inst_executed_op_fp32_pred_on.sum [inst]          300 non-null    int64
#  8   smsp__sass_thread_inst_executed_op_fp64_pred_on.sum [inst]          300 non-null    int64
#  9   smsp__sass_thread_inst_executed_op_integer_pred_on.sum [inst]       300 non-null    int64
# dtypes: float64(3), int64(5), object(2)
# memory usage: 23.6+ KB
# None
# Data types: Demangled Name                                                         object
# sm__pipe_tensor_cycles_active.avg.pct_of_peak_sustained_active [%]    float64
# smsp__sass_thread_inst_executed_op_fp16_pred_on.sum [inst]              int64
# smsp__sass_thread_inst_executed_op_fp32_pred_on.sum [inst]              int64
# smsp__sass_thread_inst_executed_op_fp64_pred_on.sum [inst]              int64
# smsp__sass_thread_inst_executed_op_integer_pred_on.sum [inst]           int64
# dtype: object
# === End of Processing: ncu_report_full_q4_2layers_utilization.csv

# %%
q8_agg = get_aggregated_stat(q8_data_file)
# Out:
# === Reading data: ncu_report_full_q8_2layers_utilization.csv
# Interested metrics in data file: 5
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 10 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   ID                                                                  300 non-null    int64
#  1   Estimated Speedup                                                   300 non-null    float64
#  2   Runtime Improvement""(0)                                            300 non-null    float64
#  3   Function Name                                                       300 non-null    object
#  4   Demangled Name                                                      300 non-null    object
#  5   sm__pipe_tensor_cycles_active.avg.pct_of_peak_sustained_active [%]  300 non-null    float64
#  6   smsp__sass_thread_inst_executed_op_fp16_pred_on.sum [inst]          300 non-null    int64
#  7   smsp__sass_thread_inst_executed_op_fp32_pred_on.sum [inst]          300 non-null    int64
#  8   smsp__sass_thread_inst_executed_op_fp64_pred_on.sum [inst]          300 non-null    int64
#  9   smsp__sass_thread_inst_executed_op_integer_pred_on.sum [inst]       300 non-null    int64
# dtypes: float64(3), int64(5), object(2)
# memory usage: 23.6+ KB
# None
# Data types: Demangled Name                                                         object
# sm__pipe_tensor_cycles_active.avg.pct_of_peak_sustained_active [%]    float64
# smsp__sass_thread_inst_executed_op_fp16_pred_on.sum [inst]              int64
# smsp__sass_thread_inst_executed_op_fp32_pred_on.sum [inst]              int64
# smsp__sass_thread_inst_executed_op_fp64_pred_on.sum [inst]              int64
# smsp__sass_thread_inst_executed_op_integer_pred_on.sum [inst]           int64
# dtype: object
# === End of Processing: ncu_report_full_q8_2layers_utilization.csv

# %%
# pd.options.display.float_format = '{:.0f}'.format
pd.options.display.float_format = '{:,.2f}'.format

# %%
q4_agg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21 entries, k_compute_batched_ptrs(const __half *, const __half *, char *, const void **, void **, long, long, long, unsigned long, unsigned long, unsigned long, unsigned long, unsigned long, unsigned long, long, long) to void soft_max_f32<(bool)1, (int)64, (int)64>(const float *, const float *, float *, int, int, float)
# Data columns (total 5 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   sm__pipe_tensor_cycles_active.avg.pct_of_peak_sustained_active [%]  21 non-null     float64
#  1   smsp__sass_thread_inst_executed_op_fp16_pred_on.sum [inst]          21 non-null     float64
#  2   smsp__sass_thread_inst_executed_op_fp32_pred_on.sum [inst]          21 non-null     float64
#  3   smsp__sass_thread_inst_executed_op_fp64_pred_on.sum [inst]          21 non-null     float64
#  4   smsp__sass_thread_inst_executed_op_integer_pred_on.sum [inst]       21 non-null     float64
# dtypes: float64(5)
# memory usage: 1008.0+ bytes

# %%
q4_agg["smsp__sass_thread_inst_executed_op_fp16_pred_on.sum [inst]"]
# Out:
# Demangled Name
# k_compute_batched_ptrs(const __half *, const __half *, char *, const void **, void **, long, long, long, unsigned long, unsigned long, unsigned long, unsigned long, unsigned long, unsigned long, long, long)                0
# k_sum_rows_f32(const float *, float *, int)                                                                                                                                                                                   0
# quantize_q8_1(const float *, void *, int, int)                                                                                                                                                                                0
# silu_f32(const float *, float *, int)                                                                                                                                                                                         0
# turing_h1688gemm_256x64_ldg8_stages_32x1_tn                                                                                                                                                                             1839104
# void convert_unary<__half, float>(const void *, T2 *, int)                                                                                                                                                                 3072
# void convert_unary<float, __half>(const void *, T2 *, int)                                                                                                                                                                    0
# void cpy_f32_f16<&cpy_1_f32_f16>(const char *, char *, int, int, int, int, int, int, int, int, int, int, int)                                                                                                                 0
# void cpy_f32_f16<&cpy_1_f32_f32>(const char *, char *, int, int, int, int, int, int, int, int, int, int, int)                                                                                                                 0
# void dequantize_mul_mat_vec<(int)1, (int)1, &convert_f16>(const void *, const float *, float *, int, int)                                                                                                                 32768
# void k_argsort_f32_i32<(ggml_sort_order)1>(const float *, int *, int)                                                                                                                                                         0
# void k_bin_bcast<&op_add, float, float, float>(const T2 *, const T3 *, T4 *, int, int, int, int, int, int, int, int, int, int, int, int, int, int)                                                                            0
# void k_bin_bcast<&op_div, float, float, float>(const T2 *, const T3 *, T4 *, int, int, int, int, int, int, int, int, int, int, int, int, int, int)                                                                            0
# void k_bin_bcast<&op_mul, float, float, float>(const T2 *, const T3 *, T4 *, int, int, int, int, int, int, int, int, int, int, int, int, int, int)                                                                            0
# void k_get_rows_float<float, float>(const T1 *, const int *, T2 *, long, long, unsigned long, unsigned long, unsigned long, unsigned long, unsigned long, unsigned long, unsigned long, unsigned long, unsigned long)         0
# void mul_mat_vec_q<(int)32, (int)4, block_q4_0, (int)2, &vec_dot_q4_0_q8_1>(const void *, const void *, float *, int, int)                                                                                              9300413
# void mul_mat_vec_q<(int)32, (int)8, block_q8_0, (int)2, &vec_dot_q8_0_q8_1>(const void *, const void *, float *, int, int)                                                                                              1048576
# void rms_norm_f32<(int)1024>(const float *, float *, int, float)                                                                                                                                                              0
# void rope<float, (bool)1>(const T1 *, T1 *, int, const int *, float, int, float, float, float, rope_corr_dims)                                                                                                                0
# void soft_max_f32<(bool)1, (int)0, (int)0>(const float *, const float *, float *, int, int, float)                                                                                                                            0
# void soft_max_f32<(bool)1, (int)64, (int)64>(const float *, const float *, float *, int, int, float)                                                                                                                          0
# Name: smsp__sass_thread_inst_executed_op_fp16_pred_on.sum [inst], dtype: float64

# %%
q4_agg.sort_values(by=['sm__pipe_tensor_cycles_active.avg.pct_of_peak_sustained_active [%]'], ascending=False)
# Out:
#                                                     sm__pipe_tensor_cycles_active.avg.pct_of_peak_sustained_active [%]  \
# Demangled Name
# turing_h1688gemm_256x64_ldg8_stages_32x1_tn                                                     29.32
# void mul_mat_vec_q<(int)32, (int)4, block_q4_0,...                                               0.06
# void mul_mat_vec_q<(int)32, (int)8, block_q8_0,...                                               0.02
# k_compute_batched_ptrs(const __half *, const __...                                               0.00
# void k_bin_bcast<&op_add, float, float, float>(...                                               0.00
# void soft_max_f32<(bool)1, (int)0, (int)0>(cons...                                               0.00
# void rope<float, (bool)1>(const T1 *, T1 *, int...                                               0.00
# void rms_norm_f32<(int)1024>(const float *, flo...                                               0.00
# void k_get_rows_float<float, float>(const T1 *,...                                               0.00
# void k_bin_bcast<&op_mul, float, float, float>(...                                               0.00
# void k_bin_bcast<&op_div, float, float, float>(...                                               0.00
# void k_argsort_f32_i32<(ggml_sort_order)1>(cons...                                               0.00
# k_sum_rows_f32(const float *, float *, int)                                                      0.00
# void dequantize_mul_mat_vec<(int)1, (int)1, &co...                                               0.00
# void cpy_f32_f16<&cpy_1_f32_f32>(const char *, ...                                               0.00
# void cpy_f32_f16<&cpy_1_f32_f16>(const char *, ...                                               0.00
# void convert_unary<float, __half>(const void *,...                                               0.00
# void convert_unary<__half, float>(const void *,...                                               0.00
# silu_f32(const float *, float *, int)                                                            0.00
# quantize_q8_1(const float *, void *, int, int)                                                   0.00
# void soft_max_f32<(bool)1, (int)64, (int)64>(co...                                               0.00
#
#                                                     smsp__sass_thread_inst_executed_op_fp16_pred_on.sum [inst]  \
# Demangled Name
# turing_h1688gemm_256x64_ldg8_stages_32x1_tn                                              1,839,104.00
# void mul_mat_vec_q<(int)32, (int)4, block_q4_0,...                                       9,300,413.22
# void mul_mat_vec_q<(int)32, (int)8, block_q8_0,...                                       1,048,576.00
# k_compute_batched_ptrs(const __half *, const __...                                               0.00
# void k_bin_bcast<&op_add, float, float, float>(...                                               0.00
# void soft_max_f32<(bool)1, (int)0, (int)0>(cons...                                               0.00
# void rope<float, (bool)1>(const T1 *, T1 *, int...                                               0.00
# void rms_norm_f32<(int)1024>(const float *, flo...                                               0.00
# void k_get_rows_float<float, float>(const T1 *,...                                               0.00
# void k_bin_bcast<&op_mul, float, float, float>(...                                               0.00
# void k_bin_bcast<&op_div, float, float, float>(...                                               0.00
# void k_argsort_f32_i32<(ggml_sort_order)1>(cons...                                               0.00
# k_sum_rows_f32(const float *, float *, int)                                                      0.00
# void dequantize_mul_mat_vec<(int)1, (int)1, &co...                                          32,768.00
# void cpy_f32_f16<&cpy_1_f32_f32>(const char *, ...                                               0.00
# void cpy_f32_f16<&cpy_1_f32_f16>(const char *, ...                                               0.00
# void convert_unary<float, __half>(const void *,...                                               0.00
# void convert_unary<__half, float>(const void *,...                                           3,072.00
# silu_f32(const float *, float *, int)                                                            0.00
# quantize_q8_1(const float *, void *, int, int)                                                   0.00
# void soft_max_f32<(bool)1, (int)64, (int)64>(co...                                               0.00
#
#                                                     smsp__sass_thread_inst_executed_op_fp32_pred_on.sum [inst]  \
# Demangled Name
# turing_h1688gemm_256x64_ldg8_stages_32x1_tn                                                      0.00
# void mul_mat_vec_q<(int)32, (int)4, block_q4_0,...                                      10,517,993.74
# void mul_mat_vec_q<(int)32, (int)8, block_q8_0,...                                       1,180,672.00
# k_compute_batched_ptrs(const __half *, const __...                                              64.00
# void k_bin_bcast<&op_add, float, float, float>(...                                          14,336.00
# void soft_max_f32<(bool)1, (int)0, (int)0>(cons...                                             408.00
# void rope<float, (bool)1>(const T1 *, T1 *, int...                                          23,040.00
# void rms_norm_f32<(int)1024>(const float *, flo...                                          21,504.00
# void k_get_rows_float<float, float>(const T1 *,...                                             512.00
# void k_bin_bcast<&op_mul, float, float, float>(...                                          25,959.78
# void k_bin_bcast<&op_div, float, float, float>(...                                               9.00
# void k_argsort_f32_i32<(ggml_sort_order)1>(cons...                                              24.00
# k_sum_rows_f32(const float *, float *, int)                                                    131.00
# void dequantize_mul_mat_vec<(int)1, (int)1, &co...                                          33,800.00
# void cpy_f32_f16<&cpy_1_f32_f32>(const char *, ...                                          16,384.00
# void cpy_f32_f16<&cpy_1_f32_f16>(const char *, ...                                           4,096.00
# void convert_unary<float, __half>(const void *,...                                               0.00
# void convert_unary<__half, float>(const void *,...                                               0.00
# silu_f32(const float *, float *, int)                                                       71,680.00
# quantize_q8_1(const float *, void *, int, int)                                              95,150.55
# void soft_max_f32<(bool)1, (int)64, (int)64>(co...                                          59,392.00
#
#                                                     smsp__sass_thread_inst_executed_op_fp64_pred_on.sum [inst]  \
# Demangled Name
# turing_h1688gemm_256x64_ldg8_stages_32x1_tn                                                      0.00
# void mul_mat_vec_q<(int)32, (int)4, block_q4_0,...                                               0.00
# void mul_mat_vec_q<(int)32, (int)8, block_q8_0,...                                               0.00
# k_compute_batched_ptrs(const __half *, const __...                                               0.00
# void k_bin_bcast<&op_add, float, float, float>(...                                               0.00
# void soft_max_f32<(bool)1, (int)0, (int)0>(cons...                                               0.00
# void rope<float, (bool)1>(const T1 *, T1 *, int...                                               0.00
# void rms_norm_f32<(int)1024>(const float *, flo...                                               0.00
# void k_get_rows_float<float, float>(const T1 *,...                                               0.00
# void k_bin_bcast<&op_mul, float, float, float>(...                                               0.00
# void k_bin_bcast<&op_div, float, float, float>(...                                               0.00
# void k_argsort_f32_i32<(ggml_sort_order)1>(cons...                                               0.00
# k_sum_rows_f32(const float *, float *, int)                                                      0.00
# void dequantize_mul_mat_vec<(int)1, (int)1, &co...                                               0.00
# void cpy_f32_f16<&cpy_1_f32_f32>(const char *, ...                                               0.00
# void cpy_f32_f16<&cpy_1_f32_f16>(const char *, ...                                               0.00
# void convert_unary<float, __half>(const void *,...                                               0.00
# void convert_unary<__half, float>(const void *,...                                               0.00
# silu_f32(const float *, float *, int)                                                            0.00
# quantize_q8_1(const float *, void *, int, int)                                                   0.00
# void soft_max_f32<(bool)1, (int)64, (int)64>(co...                                               0.00
#
#                                                     smsp__sass_thread_inst_executed_op_integer_pred_on.sum [inst]
# Demangled Name
# turing_h1688gemm_256x64_ldg8_stages_32x1_tn                                              1,775,616.00
# void mul_mat_vec_q<(int)32, (int)4, block_q4_0,...                                      56,186,078.61
# void mul_mat_vec_q<(int)32, (int)8, block_q8_0,...                                       3,245,056.00
# k_compute_batched_ptrs(const __half *, const __...                                           2,062.00
# void k_bin_bcast<&op_add, float, float, float>(...                                         245,760.00
# void soft_max_f32<(bool)1, (int)0, (int)0>(cons...                                             824.00
# void rope<float, (bool)1>(const T1 *, T1 *, int...                                          39,680.00
# void rms_norm_f32<(int)1024>(const float *, flo...                                          34,880.00
# void k_get_rows_float<float, float>(const T1 *,...                                           9,824.00
# void k_bin_bcast<&op_mul, float, float, float>(...                                         446,685.00
# void k_bin_bcast<&op_div, float, float, float>(...                                             121.00
# void k_argsort_f32_i32<(ggml_sort_order)1>(cons...                                             672.00
# k_sum_rows_f32(const float *, float *, int)                                                     73.00
# void dequantize_mul_mat_vec<(int)1, (int)1, &co...                                          37,896.00
# void cpy_f32_f16<&cpy_1_f32_f32>(const char *, ...                                         356,414.00
# void cpy_f32_f16<&cpy_1_f32_f16>(const char *, ...                                          91,141.00
# void convert_unary<float, __half>(const void *,...                                          12,288.00
# void convert_unary<__half, float>(const void *,...                                          12,288.00
# silu_f32(const float *, float *, int)                                                       57,344.00
# quantize_q8_1(const float *, void *, int, int)                                             133,725.09
# void soft_max_f32<(bool)1, (int)64, (int)64>(co...                                          61,376.00

# %%
q8_agg.sort_values(by=['sm__pipe_tensor_cycles_active.avg.pct_of_peak_sustained_active [%]'], ascending=False)
# Out:
#                                                     sm__pipe_tensor_cycles_active.avg.pct_of_peak_sustained_active [%]  \
# Demangled Name
# turing_h1688gemm_256x64_ldg8_stages_32x1_tn                                                     29.11
# void mul_mat_vec_q<(int)32, (int)8, block_q8_0,...                                               0.02
# k_compute_batched_ptrs(const __half *, const __...                                               0.00
# void k_bin_bcast<&op_add, float, float, float>(...                                               0.00
# void soft_max_f32<(bool)1, (int)0, (int)0>(cons...                                               0.00
# void rope<float, (bool)1>(const T1 *, T1 *, int...                                               0.00
# void rms_norm_f32<(int)1024>(const float *, flo...                                               0.00
# void k_get_rows_float<float, float>(const T1 *,...                                               0.00
# void k_bin_bcast<&op_mul, float, float, float>(...                                               0.00
# void k_bin_bcast<&op_div, float, float, float>(...                                               0.00
# void k_argsort_f32_i32<(ggml_sort_order)1>(cons...                                               0.00
# k_sum_rows_f32(const float *, float *, int)                                                      0.00
# void dequantize_mul_mat_vec<(int)1, (int)1, &co...                                               0.00
# void cpy_f32_f16<&cpy_1_f32_f32>(const char *, ...                                               0.00
# void cpy_f32_f16<&cpy_1_f32_f16>(const char *, ...                                               0.00
# void convert_unary<float, __half>(const void *,...                                               0.00
# void convert_unary<__half, float>(const void *,...                                               0.00
# silu_f32(const float *, float *, int)                                                            0.00
# quantize_q8_1(const float *, void *, int, int)                                                   0.00
# void soft_max_f32<(bool)1, (int)64, (int)64>(co...                                               0.00
#
#                                                     smsp__sass_thread_inst_executed_op_fp16_pred_on.sum [inst]  \
# Demangled Name
# turing_h1688gemm_256x64_ldg8_stages_32x1_tn                                              1,839,104.00
# void mul_mat_vec_q<(int)32, (int)8, block_q8_0,...                                      10,373,412.57
# k_compute_batched_ptrs(const __half *, const __...                                               0.00
# void k_bin_bcast<&op_add, float, float, float>(...                                               0.00
# void soft_max_f32<(bool)1, (int)0, (int)0>(cons...                                               0.00
# void rope<float, (bool)1>(const T1 *, T1 *, int...                                               0.00
# void rms_norm_f32<(int)1024>(const float *, flo...                                               0.00
# void k_get_rows_float<float, float>(const T1 *,...                                               0.00
# void k_bin_bcast<&op_mul, float, float, float>(...                                               0.00
# void k_bin_bcast<&op_div, float, float, float>(...                                               0.00
# void k_argsort_f32_i32<(ggml_sort_order)1>(cons...                                               0.00
# k_sum_rows_f32(const float *, float *, int)                                                      0.00
# void dequantize_mul_mat_vec<(int)1, (int)1, &co...                                          32,768.00
# void cpy_f32_f16<&cpy_1_f32_f32>(const char *, ...                                               0.00
# void cpy_f32_f16<&cpy_1_f32_f16>(const char *, ...                                               0.00
# void convert_unary<float, __half>(const void *,...                                               0.00
# void convert_unary<__half, float>(const void *,...                                           3,072.00
# silu_f32(const float *, float *, int)                                                            0.00
# quantize_q8_1(const float *, void *, int, int)                                                   0.00
# void soft_max_f32<(bool)1, (int)64, (int)64>(co...                                               0.00
#
#                                                     smsp__sass_thread_inst_executed_op_fp32_pred_on.sum [inst]  \
# Demangled Name
# turing_h1688gemm_256x64_ldg8_stages_32x1_tn                                                      0.00
# void mul_mat_vec_q<(int)32, (int)8, block_q8_0,...                                      11,397,156.57
# k_compute_batched_ptrs(const __half *, const __...                                              64.00
# void k_bin_bcast<&op_add, float, float, float>(...                                          14,336.00
# void soft_max_f32<(bool)1, (int)0, (int)0>(cons...                                             408.00
# void rope<float, (bool)1>(const T1 *, T1 *, int...                                          23,040.00
# void rms_norm_f32<(int)1024>(const float *, flo...                                          21,504.00
# void k_get_rows_float<float, float>(const T1 *,...                                             512.00
# void k_bin_bcast<&op_mul, float, float, float>(...                                          25,959.78
# void k_bin_bcast<&op_div, float, float, float>(...                                               9.00
# void k_argsort_f32_i32<(ggml_sort_order)1>(cons...                                              24.00
# k_sum_rows_f32(const float *, float *, int)                                                    131.00
# void dequantize_mul_mat_vec<(int)1, (int)1, &co...                                          33,800.00
# void cpy_f32_f16<&cpy_1_f32_f32>(const char *, ...                                          16,384.00
# void cpy_f32_f16<&cpy_1_f32_f16>(const char *, ...                                           4,096.00
# void convert_unary<float, __half>(const void *,...                                               0.00
# void convert_unary<__half, float>(const void *,...                                               0.00
# silu_f32(const float *, float *, int)                                                       71,680.00
# quantize_q8_1(const float *, void *, int, int)                                              94,550.86
# void soft_max_f32<(bool)1, (int)64, (int)64>(co...                                          59,392.00
#
#                                                     smsp__sass_thread_inst_executed_op_fp64_pred_on.sum [inst]  \
# Demangled Name
# turing_h1688gemm_256x64_ldg8_stages_32x1_tn                                                      0.00
# void mul_mat_vec_q<(int)32, (int)8, block_q8_0,...                                               0.00
# k_compute_batched_ptrs(const __half *, const __...                                               0.00
# void k_bin_bcast<&op_add, float, float, float>(...                                               0.00
# void soft_max_f32<(bool)1, (int)0, (int)0>(cons...                                               0.00
# void rope<float, (bool)1>(const T1 *, T1 *, int...                                               0.00
# void rms_norm_f32<(int)1024>(const float *, flo...                                               0.00
# void k_get_rows_float<float, float>(const T1 *,...                                               0.00
# void k_bin_bcast<&op_mul, float, float, float>(...                                               0.00
# void k_bin_bcast<&op_div, float, float, float>(...                                               0.00
# void k_argsort_f32_i32<(ggml_sort_order)1>(cons...                                               0.00
# k_sum_rows_f32(const float *, float *, int)                                                      0.00
# void dequantize_mul_mat_vec<(int)1, (int)1, &co...                                               0.00
# void cpy_f32_f16<&cpy_1_f32_f32>(const char *, ...                                               0.00
# void cpy_f32_f16<&cpy_1_f32_f16>(const char *, ...                                               0.00
# void convert_unary<float, __half>(const void *,...                                               0.00
# void convert_unary<__half, float>(const void *,...                                               0.00
# silu_f32(const float *, float *, int)                                                            0.00
# quantize_q8_1(const float *, void *, int, int)                                                   0.00
# void soft_max_f32<(bool)1, (int)64, (int)64>(co...                                               0.00
#
#                                                     smsp__sass_thread_inst_executed_op_integer_pred_on.sum [inst]
# Demangled Name
# turing_h1688gemm_256x64_ldg8_stages_32x1_tn                                              1,775,616.00
# void mul_mat_vec_q<(int)32, (int)8, block_q8_0,...                                      30,485,686.86
# k_compute_batched_ptrs(const __half *, const __...                                           2,062.00
# void k_bin_bcast<&op_add, float, float, float>(...                                         245,760.00
# void soft_max_f32<(bool)1, (int)0, (int)0>(cons...                                             824.00
# void rope<float, (bool)1>(const T1 *, T1 *, int...                                          39,680.00
# void rms_norm_f32<(int)1024>(const float *, flo...                                          34,880.00
# void k_get_rows_float<float, float>(const T1 *,...                                           9,824.00
# void k_bin_bcast<&op_mul, float, float, float>(...                                         446,574.32
# void k_bin_bcast<&op_div, float, float, float>(...                                             121.00
# void k_argsort_f32_i32<(ggml_sort_order)1>(cons...                                             672.00
# k_sum_rows_f32(const float *, float *, int)                                                     73.00
# void dequantize_mul_mat_vec<(int)1, (int)1, &co...                                          37,896.00
# void cpy_f32_f16<&cpy_1_f32_f32>(const char *, ...                                         356,414.00
# void cpy_f32_f16<&cpy_1_f32_f16>(const char *, ...                                          91,141.00
# void convert_unary<float, __half>(const void *,...                                          12,288.00
# void convert_unary<__half, float>(const void *,...                                          12,288.00
# silu_f32(const float *, float *, int)                                                       57,344.00
# quantize_q8_1(const float *, void *, int, int)                                             132,882.29
# void soft_max_f32<(bool)1, (int)64, (int)64>(co...                                          61,376.00

# %%
q8_agg.sub(q4_agg, fill_value=0.0)
# Out:
#                                                     sm__pipe_tensor_cycles_active.avg.pct_of_peak_sustained_active [%]  \
# Demangled Name
# k_compute_batched_ptrs(const __half *, const __...                                                  0
# k_sum_rows_f32(const float *, float *, int)                                                         0
# quantize_q8_1(const float *, void *, int, int)                                                      0
# silu_f32(const float *, float *, int)                                                               0
# turing_h1688gemm_256x64_ldg8_stages_32x1_tn                                                        -0
# void convert_unary<__half, float>(const void *,...                                                  0
# void convert_unary<float, __half>(const void *,...                                                  0
# void cpy_f32_f16<&cpy_1_f32_f16>(const char *, ...                                                  0
# void cpy_f32_f16<&cpy_1_f32_f32>(const char *, ...                                                  0
# void dequantize_mul_mat_vec<(int)1, (int)1, &co...                                                  0
# void k_argsort_f32_i32<(ggml_sort_order)1>(cons...                                                  0
# void k_bin_bcast<&op_add, float, float, float>(...                                                  0
# void k_bin_bcast<&op_div, float, float, float>(...                                                  0
# void k_bin_bcast<&op_mul, float, float, float>(...                                                  0
# void k_get_rows_float<float, float>(const T1 *,...                                                  0
# void mul_mat_vec_q<(int)32, (int)4, block_q4_0,...                                                 -0
# void mul_mat_vec_q<(int)32, (int)8, block_q8_0,...                                                  0
# void rms_norm_f32<(int)1024>(const float *, flo...                                                  0
# void rope<float, (bool)1>(const T1 *, T1 *, int...                                                  0
# void soft_max_f32<(bool)1, (int)0, (int)0>(cons...                                                  0
# void soft_max_f32<(bool)1, (int)64, (int)64>(co...                                                  0
#
#                                                     smsp__sass_thread_inst_executed_op_fp16_pred_on.sum [inst]  \
# Demangled Name
# k_compute_batched_ptrs(const __half *, const __...                                                  0
# k_sum_rows_f32(const float *, float *, int)                                                         0
# quantize_q8_1(const float *, void *, int, int)                                                      0
# silu_f32(const float *, float *, int)                                                               0
# turing_h1688gemm_256x64_ldg8_stages_32x1_tn                                                         0
# void convert_unary<__half, float>(const void *,...                                                  0
# void convert_unary<float, __half>(const void *,...                                                  0
# void cpy_f32_f16<&cpy_1_f32_f16>(const char *, ...                                                  0
# void cpy_f32_f16<&cpy_1_f32_f32>(const char *, ...                                                  0
# void dequantize_mul_mat_vec<(int)1, (int)1, &co...                                                  0
# void k_argsort_f32_i32<(ggml_sort_order)1>(cons...                                                  0
# void k_bin_bcast<&op_add, float, float, float>(...                                                  0
# void k_bin_bcast<&op_div, float, float, float>(...                                                  0
# void k_bin_bcast<&op_mul, float, float, float>(...                                                  0
# void k_get_rows_float<float, float>(const T1 *,...                                                  0
# void mul_mat_vec_q<(int)32, (int)4, block_q4_0,...                                           -9300413
# void mul_mat_vec_q<(int)32, (int)8, block_q8_0,...                                            9324837
# void rms_norm_f32<(int)1024>(const float *, flo...                                                  0
# void rope<float, (bool)1>(const T1 *, T1 *, int...                                                  0
# void soft_max_f32<(bool)1, (int)0, (int)0>(cons...                                                  0
# void soft_max_f32<(bool)1, (int)64, (int)64>(co...                                                  0
#
#                                                     smsp__sass_thread_inst_executed_op_fp32_pred_on.sum [inst]  \
# Demangled Name
# k_compute_batched_ptrs(const __half *, const __...                                                  0
# k_sum_rows_f32(const float *, float *, int)                                                         0
# quantize_q8_1(const float *, void *, int, int)                                                   -600
# silu_f32(const float *, float *, int)                                                               0
# turing_h1688gemm_256x64_ldg8_stages_32x1_tn                                                         0
# void convert_unary<__half, float>(const void *,...                                                  0
# void convert_unary<float, __half>(const void *,...                                                  0
# void cpy_f32_f16<&cpy_1_f32_f16>(const char *, ...                                                  0
# void cpy_f32_f16<&cpy_1_f32_f32>(const char *, ...                                                  0
# void dequantize_mul_mat_vec<(int)1, (int)1, &co...                                                  0
# void k_argsort_f32_i32<(ggml_sort_order)1>(cons...                                                  0
# void k_bin_bcast<&op_add, float, float, float>(...                                                  0
# void k_bin_bcast<&op_div, float, float, float>(...                                                  0
# void k_bin_bcast<&op_mul, float, float, float>(...                                                  0
# void k_get_rows_float<float, float>(const T1 *,...                                                  0
# void mul_mat_vec_q<(int)32, (int)4, block_q4_0,...                                          -10517994
# void mul_mat_vec_q<(int)32, (int)8, block_q8_0,...                                           10216485
# void rms_norm_f32<(int)1024>(const float *, flo...                                                  0
# void rope<float, (bool)1>(const T1 *, T1 *, int...                                                  0
# void soft_max_f32<(bool)1, (int)0, (int)0>(cons...                                                  0
# void soft_max_f32<(bool)1, (int)64, (int)64>(co...                                                  0
#
#                                                     smsp__sass_thread_inst_executed_op_fp64_pred_on.sum [inst]  \
# Demangled Name
# k_compute_batched_ptrs(const __half *, const __...                                                  0
# k_sum_rows_f32(const float *, float *, int)                                                         0
# quantize_q8_1(const float *, void *, int, int)                                                      0
# silu_f32(const float *, float *, int)                                                               0
# turing_h1688gemm_256x64_ldg8_stages_32x1_tn                                                         0
# void convert_unary<__half, float>(const void *,...                                                  0
# void convert_unary<float, __half>(const void *,...                                                  0
# void cpy_f32_f16<&cpy_1_f32_f16>(const char *, ...                                                  0
# void cpy_f32_f16<&cpy_1_f32_f32>(const char *, ...                                                  0
# void dequantize_mul_mat_vec<(int)1, (int)1, &co...                                                  0
# void k_argsort_f32_i32<(ggml_sort_order)1>(cons...                                                  0
# void k_bin_bcast<&op_add, float, float, float>(...                                                  0
# void k_bin_bcast<&op_div, float, float, float>(...                                                  0
# void k_bin_bcast<&op_mul, float, float, float>(...                                                  0
# void k_get_rows_float<float, float>(const T1 *,...                                                  0
# void mul_mat_vec_q<(int)32, (int)4, block_q4_0,...                                                  0
# void mul_mat_vec_q<(int)32, (int)8, block_q8_0,...                                                  0
# void rms_norm_f32<(int)1024>(const float *, flo...                                                  0
# void rope<float, (bool)1>(const T1 *, T1 *, int...                                                  0
# void soft_max_f32<(bool)1, (int)0, (int)0>(cons...                                                  0
# void soft_max_f32<(bool)1, (int)64, (int)64>(co...                                                  0
#
#                                                     smsp__sass_thread_inst_executed_op_integer_pred_on.sum [inst]
# Demangled Name
# k_compute_batched_ptrs(const __half *, const __...                                                  0
# k_sum_rows_f32(const float *, float *, int)                                                         0
# quantize_q8_1(const float *, void *, int, int)                                                   -843
# silu_f32(const float *, float *, int)                                                               0
# turing_h1688gemm_256x64_ldg8_stages_32x1_tn                                                         0
# void convert_unary<__half, float>(const void *,...                                                  0
# void convert_unary<float, __half>(const void *,...                                                  0
# void cpy_f32_f16<&cpy_1_f32_f16>(const char *, ...                                                  0
# void cpy_f32_f16<&cpy_1_f32_f32>(const char *, ...                                                  0
# void dequantize_mul_mat_vec<(int)1, (int)1, &co...                                                  0
# void k_argsort_f32_i32<(ggml_sort_order)1>(cons...                                                  0
# void k_bin_bcast<&op_add, float, float, float>(...                                                  0
# void k_bin_bcast<&op_div, float, float, float>(...                                                  0
# void k_bin_bcast<&op_mul, float, float, float>(...                                               -111
# void k_get_rows_float<float, float>(const T1 *,...                                                  0
# void mul_mat_vec_q<(int)32, (int)4, block_q4_0,...                                          -56186079
# void mul_mat_vec_q<(int)32, (int)8, block_q8_0,...                                           27240631
# void rms_norm_f32<(int)1024>(const float *, flo...                                                  0
# void rope<float, (bool)1>(const T1 *, T1 *, int...                                                  0
# void soft_max_f32<(bool)1, (int)0, (int)0>(cons...                                                  0
# void soft_max_f32<(bool)1, (int)64, (int)64>(co...                                                  0

# %%
diff = q8_agg.sub(q4_agg, fill_value=0.0)
diff.loc[(diff!=0).any(axis=1)]
# Out:
#                                                     sm__pipe_tensor_cycles_active.avg.pct_of_peak_sustained_active [%]  \
# Demangled Name
# quantize_q8_1(const float *, void *, int, int)                                                      0
# turing_h1688gemm_256x64_ldg8_stages_32x1_tn                                                        -0
# void k_bin_bcast<&op_mul, float, float, float>(...                                                  0
# void mul_mat_vec_q<(int)32, (int)4, block_q4_0,...                                                 -0
# void mul_mat_vec_q<(int)32, (int)8, block_q8_0,...                                                  0
#
#                                                     smsp__sass_thread_inst_executed_op_fp16_pred_on.sum [inst]  \
# Demangled Name
# quantize_q8_1(const float *, void *, int, int)                                                      0
# turing_h1688gemm_256x64_ldg8_stages_32x1_tn                                                         0
# void k_bin_bcast<&op_mul, float, float, float>(...                                                  0
# void mul_mat_vec_q<(int)32, (int)4, block_q4_0,...                                           -9300413
# void mul_mat_vec_q<(int)32, (int)8, block_q8_0,...                                            9324837
#
#                                                     smsp__sass_thread_inst_executed_op_fp32_pred_on.sum [inst]  \
# Demangled Name
# quantize_q8_1(const float *, void *, int, int)                                                   -600
# turing_h1688gemm_256x64_ldg8_stages_32x1_tn                                                         0
# void k_bin_bcast<&op_mul, float, float, float>(...                                                  0
# void mul_mat_vec_q<(int)32, (int)4, block_q4_0,...                                          -10517994
# void mul_mat_vec_q<(int)32, (int)8, block_q8_0,...                                           10216485
#
#                                                     smsp__sass_thread_inst_executed_op_fp64_pred_on.sum [inst]  \
# Demangled Name
# quantize_q8_1(const float *, void *, int, int)                                                      0
# turing_h1688gemm_256x64_ldg8_stages_32x1_tn                                                         0
# void k_bin_bcast<&op_mul, float, float, float>(...                                                  0
# void mul_mat_vec_q<(int)32, (int)4, block_q4_0,...                                                  0
# void mul_mat_vec_q<(int)32, (int)8, block_q8_0,...                                                  0
#
#                                                     smsp__sass_thread_inst_executed_op_integer_pred_on.sum [inst]
# Demangled Name
# quantize_q8_1(const float *, void *, int, int)                                                   -843
# turing_h1688gemm_256x64_ldg8_stages_32x1_tn                                                         0
# void k_bin_bcast<&op_mul, float, float, float>(...                                               -111
# void mul_mat_vec_q<(int)32, (int)4, block_q4_0,...                                          -56186079
# void mul_mat_vec_q<(int)32, (int)8, block_q8_0,...                                           27240631
